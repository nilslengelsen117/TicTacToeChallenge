# %%
"""  matrix = [
    ["1", "2", "3"],   # row 0
    ["4", "5", "6"],   # row 1
    ["7", "8", "9"]    # row 2
]

for row in matrix:
    print(row)  """
# Out:
# ['1', '2', '3']
# ['4', '5', '6']
# ['7', '8', '9']

# %%
matrix = [
    [1,2,3],   # row 0
    [4,5,6],   # row 1
    [7,8,9]    # row 2
]

for row in matrix:
    print(row)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
X = "X"
O = "O"

# %%
1 = matrix[0][0] = "X"
2 = matrix[0][1] = "X"
3 = matrix[0][2] = "X"
4 = matrix[1][0] = "X"
5 = matrix[1][1] = "X"
6 = matrix[1][2] = "X"
7 = matrix[2][0] = "X"
8 = matrix[2][1] = "X"
9 = matrix[2][2] = "X"


for row in matrix:
    print(row)
# Out:
#   Cell In[27], line 1
#     1 = matrix[0][0] = "X"
#     ^
# SyntaxError: cannot assign to literal

# %%
1 = matrix[0][0] = "X"

for row in matrix:
    print(row)
# Out:
#   Cell In[22], line 1
#     1 = matrix[0][0] = "X"
#     ^
# SyntaxError: cannot assign to literal
