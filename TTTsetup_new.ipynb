# %%
"""  matrix = [
    ["1", "2", "3"],   # row 0
    ["4", "5", "6"],   # row 1
    ["7", "8", "9"]    # row 2
]

for row in matrix:
    print(row)  """
# Out:
# '  matrix = [\n    ["1", "2", "3"],   # row 0\n    ["4", "5", "6"],   # row 1\n    ["7", "8", "9"]    # row 2\n]\n\nfor row in matrix:\n    print(row)  '

# %%
matrix = [
    [1,2,3],   # row 0
    [4,5,6],   # row 1
    [7,8,9]    # row 2
]

for row in matrix:
    print(row)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
X = "X"
O = "O"

# %%
matrix[0][0] = "X"
matrix[0][1] = "X"
matrix[0][2] = "X"
matrix[1][0] = "X"
matrix[1][1] = "X"
matrix[1][2] = "X"
matrix[2][0] = "X"
matrix[2][1] = "X"
matrix[2][2] = "X"


for row in matrix:
    print(row)
# Out:
# ['X', 'X', 'X']
# ['X', 'X', 'X']
# ['X', 'X', 'X']

# %%
# player one chooses number 5:
matrix[1][1] = "O"
for row in matrix:
    print(row)

# player two chooses number 1:
matrix[0][0] = "X"
for row in matrix:
    print(row)

# after several turns, the board looks like this:
matrix = [
    ["X", "O", "X"],   # row 0
    ["4", "O", "6"],   # row 1
    ["X", "8", "O"]    # row 2
]

# if player one chooses number 4, they win!
matrix[1][0] = "X"
for row in matrix:
    print(row)

# if player one does not type a number but something else, show an error message

def choose_number(input_value):
    if input_value not in ['1','2','3','4','5','6','7','8','9']:
        print("Error: Invalid input. Please choose a number between 1 and 9.")
    else:
        print(f"You chose number {input_value}.")
choose_number('a')  # Example of invalid input
choose_number('5')  # Example of valid input
choose_number('10')  # Example of invalid input

# if the board is full and there is no winner, declare a tie:
def check_tie(board):
    for row in board:
        for cell in row:
            if cell not in ['X', 'O']:
                return False
    return True
# game over play again, restart the game
# def restart_game():


""" example full_board = [
    ["X", "O", "X"],
    ["X", "O", "O"],
    ["O", "X", "X"]
]
 """
# Out:
# ['X', 'X', 'X']
# ['X', 'O', 'X']
# ['X', 'X', 'X']
# ['X', 'X', 'X']
# ['X', 'O', 'X']
# ['X', 'X', 'X']
# ['X', 'O', 'X']
# ['X', 'O', '6']
# ['X', '8', 'O']
# Error: Invalid input. Please choose a number between 1 and 9.
# You chose number 5.
# Error: Invalid input. Please choose a number between 1 and 9.

# %%
1 = matrix[0][0] = "X"

for row in matrix:
    print(row)
# Out:
#   Cell In[10], line 1
#     1 = matrix[0][0] = "X"
#     ^
# SyntaxError: cannot assign to literal
