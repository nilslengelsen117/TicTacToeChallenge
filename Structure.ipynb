# %% [markdown]
# #Tic Tac Toe Functions
#
# - Write a game intro
# - Display a table/grid 3x3 and update it after every input
# - Allow user input (e.g. write a coordinate where to/or choose a cell from 1-9)
# - Check user input for validity and give feedback
# - Check if someone has won (end game condition)
# - Check if there is no empty cell left in the grid (end game condition)
